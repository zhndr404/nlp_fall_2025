# %% [markdown]
# ### Pandas: Work with lines! [Homework]
# > ** You must import all the necessary packages yourself. **
#
# > ** Write the code only where it is shown for recording. Do not delete comments! **

# %% [markdown]
# ### Step 1
#
# Please write the function `` `Load_Data (Filename)` ``, which will download data from the CSV file to the list of lists. Please write the function `` Load_Data (Filename) `` `, which will download data from the CSV file to` `Dataframe``` '. The file is `` num_house_Prices.csv`` 'provided with this Jupyter Notebook.
#
#
# **Note:**
#
# * If the file name is defined incorrectly, the function is `` Load_Data`` 'The following error message should display:
#
# ```{имя файла} does not exist```
# * ```str_house_prices.csv``` - это csv-файл, который является результатом вашей предыдущей домашней работы.

# %%
import pandas as pd
import os.path
def load_data(filename):
    if os.path.exists(filename):
        pd_data = pd.read_csv(filename)
        return pd_data
    else:
        return f"file {filename} doesnt exists!"

# %%
# filename = "./SocialNetworkAds.csv"
filename = "./Social_Network_Ads.csv"
data = load_data(filename)
data
# data = load_data(filename=filenhttps://meet.google.com/tnt-deug-gkbame)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# ./SocialNetworkAds.csv does not exist
# ```

# %%
print(data)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# None
# ```

# %%
filename = "./str_house_prices.csv"
data = load_data(filename=filename)

# %%
print(data.columns.values.tolist())
# Out:
# ['Id', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# ['Id', 'MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']
# ```

# %%
data
# Out:
#         Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0        1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1        2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2        3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3        4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4        5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...    ...      ...    ...      ...         ...       ...       ...       ...
# 1333  1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1334  1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1335  1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1336  1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1337  1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 0         CollgCr       Norm  ...      SBrkr          Gd        Typ
# 1         Veenker      Feedr  ...      SBrkr          TA        Typ
# 2         CollgCr       Norm  ...      SBrkr          Gd        Typ
# 3         Crawfor       Norm  ...      SBrkr          Gd        Typ
# 4         NoRidge       Norm  ...      SBrkr          Gd        Typ
# ...           ...        ...  ...        ...         ...        ...
# 1333      Gilbert       Norm  ...      SBrkr          TA        Typ
# 1334       NWAmes       Norm  ...      SBrkr          TA       Min1
# 1335      Crawfor       Norm  ...      SBrkr          Gd        Typ
# 1336        NAmes       Norm  ...      FuseA          Gd        Typ
# 1337      Edwards       Norm  ...      SBrkr          TA        Typ
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 0        Attchd          RFn         TA         TA          Y       WD
# 1        Attchd          RFn         TA         TA          Y       WD
# 2        Attchd          RFn         TA         TA          Y       WD
# 3        Detchd          Unf         TA         TA          Y       WD
# 4        Attchd          RFn         TA         TA          Y       WD
# ...         ...          ...        ...        ...        ...      ...
# 1333     Attchd          RFn         TA         TA          Y       WD
# 1334     Attchd          Unf         TA         TA          Y       WD
# 1335     Attchd          RFn         TA         TA          Y       WD
# 1336     Attchd          Unf         TA         TA          Y       WD
# 1337     Attchd          Fin         TA         TA          Y       WD
#
#      SaleCondition
# 0           Normal
# 1           Normal
# 2           Normal
# 3          Abnorml
# 4           Normal
# ...            ...
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [1338 rows x 39 columns]

# %% [markdown]
# **Распечатайте первые и последние 5 строк pandas.DataFrame:**

# %%
#Начало вашего кода
print(data.head(5))
print(data.tail(5))
#Конец вашего кода
# Out:
#    Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0   1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1   2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2   3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3   4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4   5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... Electrical KitchenQual Functional GarageType  \
# 0      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 1      Veenker      Feedr  ...      SBrkr          TA        Typ     Attchd
# 2      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 3      Crawfor       Norm  ...      SBrkr          Gd        Typ     Detchd
# 4      NoRidge       Norm  ...      SBrkr          Gd        Typ     Attchd
#
#   GarageFinish GarageQual GarageCond PavedDrive SaleType SaleCondition
# 0          RFn         TA         TA          Y       WD        Normal
# 1          RFn         TA         TA          Y       WD        Normal
# 2          RFn         TA         TA          Y       WD        Normal
# 3          Unf         TA         TA          Y       WD       Abnorml
# 4          RFn         TA         TA          Y       WD        Normal
#
# [5 rows x 39 columns]
#         Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 1333  1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1334  1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1335  1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1336  1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1337  1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 1333      Gilbert       Norm  ...      SBrkr          TA        Typ
# 1334       NWAmes       Norm  ...      SBrkr          TA       Min1
# 1335      Crawfor       Norm  ...      SBrkr          Gd        Typ
# 1336        NAmes       Norm  ...      FuseA          Gd        Typ
# 1337      Edwards       Norm  ...      SBrkr          TA        Typ
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 1333     Attchd          RFn         TA         TA          Y       WD
# 1334     Attchd          Unf         TA         TA          Y       WD
# 1335     Attchd          RFn         TA         TA          Y       WD
# 1336     Attchd          Unf         TA         TA          Y       WD
# 1337     Attchd          Fin         TA         TA          Y       WD
#
#      SaleCondition
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [5 rows x 39 columns]

# %% [markdown]
# ###  Expected results:
#
# ```
# Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0   1       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1   2       RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2   3       RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3   4       RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4   5       RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
#
# Neighborhood Condition1  ... Electrical KitchenQual Functional GarageType  \
# 0      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 1 Veenker Feed R ... SCRKR TA PAY CHECKED
# 2      CollgCr       Norm  ...      SBrkr          Gd        Typ     Attchd
# 3      Crawfor       Norm  ...      SBrkr          Gd        Typ     Detchd
# 4      NoRidge       Norm  ...      SBrkr          Gd        Typ     Attchd
#
# GarageFinish GarageQual GarageCond PavedDrive SaleType SaleCondition
# 0 RFn NOT WA
# 1 RFn Normal WD
# 2 RFn NOT WA
# 3 UNF TA TA Y WD ABNORML
# 44 RFn NOT WA
#
# [5 rows x 39 columns]
# Id MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 1333  1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1334  1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1335  1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1336  1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1337  1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
# Neighborhood Condition1  ... Electrical KitchenQual Functional  \
# 1333 Gilbert Norm ... Sbrkr take type
# 1334 NWAMES NORM ... SBRKR TA Min1
# 1335      Crawfor       Norm  ...      SBrkr          Gd        Typ
# 1336        NAmes       Norm  ...      FuseA          Gd        Typ
# 1337 Edwards norm ... SBRK TAKE TYPE
#
# GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 1333 Atchd RFn RFn THE WD
# 1334 Attchd Unf THE WD
# 1335 Attchd RFn RFn THE WD
# 1336 Atchd Unf THE WD
# 1337 Atchd Fin THE WD
#
# Salecondition
# 1333        Normal
# 1334        Normal
# 1335        Normal
# 1336        Normal
# 1337        Normal
#
# [5 rows x 39 columns]
# ```

# %% [markdown]
# ### Step 2
#
# Run the code block below and try to get some insight into the data you are looking at.

# %%
pd_data=data.copy()
pd_data.set_index("Id",inplace=True)
pd_data
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 5          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1460       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1         CollgCr       Norm       Norm  ...      SBrkr          Gd
# 2         Veenker      Feedr       Norm  ...      SBrkr          TA
# 3         CollgCr       Norm       Norm  ...      SBrkr          Gd
# 4         Crawfor       Norm       Norm  ...      SBrkr          Gd
# 5         NoRidge       Norm       Norm  ...      SBrkr          Gd
# ...           ...        ...        ...  ...        ...         ...
# 1456      Gilbert       Norm       Norm  ...      SBrkr          TA
# 1457       NWAmes       Norm       Norm  ...      SBrkr          TA
# 1458      Crawfor       Norm       Norm  ...      SBrkr          Gd
# 1459        NAmes       Norm       Norm  ...      FuseA          Gd
# 1460      Edwards       Norm       Norm  ...      SBrkr          TA
#
#      Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1           Typ     Attchd          RFn         TA         TA          Y
# 2           Typ     Attchd          RFn         TA         TA          Y
# 3           Typ     Attchd          RFn         TA         TA          Y
# 4           Typ     Detchd          Unf         TA         TA          Y
# 5           Typ     Attchd          RFn         TA         TA          Y
# ...         ...        ...          ...        ...        ...        ...
# 1456        Typ     Attchd          RFn         TA         TA          Y
# 1457       Min1     Attchd          Unf         TA         TA          Y
# 1458        Typ     Attchd          RFn         TA         TA          Y
# 1459        Typ     Attchd          Unf         TA         TA          Y
# 1460        Typ     Attchd          Fin         TA         TA          Y
#
#      SaleType SaleCondition
# Id
# 1          WD        Normal
# 2          WD        Normal
# 3          WD        Normal
# 4          WD       Abnorml
# 5          WD        Normal
# ...       ...           ...
# 1456       WD        Normal
# 1457       WD        Normal
# 1458       WD        Normal
# 1459       WD        Normal
# 1460       WD        Normal
#
# [1338 rows x 38 columns]

# %% [markdown]
# Please implement a ```count_by_group(data,column)``` function that returns statistics by group ```column``` for column ```column``` in a ```DataFrame```. The statistics contain the number of unique values ​​in the column.

# %%
#Начало вашего кода
def count_by_group(data,column):
    if len(column) == 0:
        result_dict = {}
        for col in data.columns:
            result_dict[col] = data.groupby(col).size()
        return result_dict
    else: 
        data1 = data.groupby(column).size()
        return data1
#Конец вашего кода

# %%
print(count_by_group(pd_data, "LotShape"))
# Out:
# LotShape
# IR1    459
# IR2     40
# IR3     10
# Reg    829
# dtype: int64

# %%
data.groupby('LotShape').count()
# Out:
#            Id  MSZoning  Street  LandContour  Utilities  LotConfig  LandSlope  \
# LotShape
# IR1       459       459     459          459        459        459        459
# IR2        40        40      40           40         40         40         40
# IR3        10        10      10           10         10         10         10
# Reg       829       829     829          829        829        829        829
#
#           Neighborhood  Condition1  Condition2  ...  Electrical  KitchenQual  \
# LotShape                                        ...
# IR1                459         459         459  ...         459          459
# IR2                 40          40          40  ...          40           40
# IR3                 10          10          10  ...          10           10
# Reg                829         829         829  ...         829          829
#
#           Functional  GarageType  GarageFinish  GarageQual  GarageCond  \
# LotShape
# IR1              459         459           459         459         459
# IR2               40          40            40          40          40
# IR3               10          10            10          10          10
# Reg              829         829           829         829         829
#
#           PavedDrive  SaleType  SaleCondition
# LotShape
# IR1              459       459            459
# IR2               40        40             40
# IR3               10        10             10
# Reg              829       829            829
#
# [4 rows x 38 columns]

# %%
result=count_by_group(data=pd_data,column="LotShape")
print(result)
# Out:
# LotShape
# IR1    459
# IR2     40
# IR3     10
# Reg    829
# dtype: int64

# %% [markdown]
# ### Ожидаемый результат:
#
# ```
# Lotter
# IR1 459
# IR2     40
# IR3     10
# Reg    829
# Name: LotShape, dtype: int64
# ```

# %%
result=count_by_group(data=pd_data,column="")
print(type(result))
print(result)
# Out:
# <class 'dict'>
# {'MSZoning': MSZoning
# C (all)       8
# FV           62
# RH           11
# RL         1066
# RM          191
# dtype: int64, 'Street': Street
# Grvl       5
# Pave    1333
# dtype: int64, 'LotShape': LotShape
# IR1    459
# IR2     40
# IR3     10
# Reg    829
# dtype: int64, 'LandContour': LandContour
# Bnk      52
# HLS      48
# Low      32
# Lvl    1206
# dtype: int64, 'Utilities': Utilities
# AllPub    1337
# NoSeWa       1
# dtype: int64, 'LotConfig': LotConfig
# Corner     244
# CulDSac     90
# FR2         43
# FR3          4
# Inside     957
# dtype: int64, 'LandSlope': LandSlope
# Gtl    1265
# Mod      61
# Sev      12
# dtype: int64, 'Neighborhood': Neighborhood
# Blmngtn     17
# Blueste      2
# BrDale      15
# BrkSide     47
# ClearCr     26
# CollgCr    146
# Crawfor     50
# Edwards     70
# Gilbert     77
# IDOTRR      29
# MeadowV     12
# Mitchel     42
# NAmes      209
# NPkVill      9
# NWAmes      73
# NoRidge     41
# NridgHt     75
# OldTown    100
# SWISU       20
# Sawyer      69
# SawyerW     53
# Somerst     83
# StoneBr     25
# Timber      37
# Veenker     11
# dtype: int64, 'Condition1': Condition1
# Artery      43
# Feedr       63
# Norm      1162
# PosA         8
# PosN        19
# RRAe        10
# RRAn        26
# RRNe         2
# RRNn         5
# dtype: int64, 'Condition2': Condition2
# Artery       2
# Feedr        5
# Norm      1324
# PosA         1
# PosN         2
# RRAe         1
# RRAn         1
# RRNn         2
# dtype: int64, 'BldgType': BldgType
# 1Fam      1138
# 2fmCon      22
# Duplex      28
# Twnhs       38
# TwnhsE     112
# dtype: int64, 'HouseStyle': HouseStyle
# 1.5Fin    134
# 1.5Unf     11
# 1Story    657
# 2.5Fin      6
# 2.5Unf     10
# 2Story    426
# SFoyer     30
# SLvl       64
# dtype: int64, 'RoofStyle': RoofStyle
# Flat         11
# Gable      1037
# Gambrel      10
# Hip         272
# Mansard       6
# Shed          2
# dtype: int64, 'RoofMatl': RoofMatl
# ClyTile       1
# CompShg    1314
# Membran       1
# Metal         1
# Roll          1
# Tar&Grv       9
# WdShake       5
# WdShngl       6
# dtype: int64, 'Exterior1st': Exterior1st
# AsbShng     15
# BrkComm      1
# BrkFace     44
# CBlock       1
# CemntBd     52
# HdBoard    211
# ImStucc      1
# MetalSd    201
# Plywood    100
# Stone        2
# Stucco      21
# VinylSd    486
# Wd Sdng    183
# WdShing     20
# dtype: int64, 'Exterior2nd': Exterior2nd
# AsbShng     16
# AsphShn      2
# Brk Cmn      6
# BrkFace     22
# CBlock       1
# CmentBd     51
# HdBoard    197
# ImStucc     10
# MetalSd    197
# Other        1
# Plywood    127
# Stone        2
# Stucco      23
# VinylSd    475
# Wd Sdng    176
# Wd Shng     32
# dtype: int64, 'MasVnrType': MasVnrType
# BrkCmn      15
# BrkFace    432
# Stone      128
# dtype: int64, 'ExterQual': ExterQual
# Ex     51
# Fa      7
# Gd    477
# TA    803
# dtype: int64, 'ExterCond': ExterCond
# Ex       2
# Fa      16
# Gd     137
# TA    1183
# dtype: int64, 'Foundation': Foundation
# BrkTil    129
# CBlock    580
# PConc     620
# Stone       6
# Wood        3
# dtype: int64, 'BsmtQual': BsmtQual
# Ex    120
# Fa     32
# Gd    592
# TA    594
# dtype: int64, 'BsmtCond': BsmtCond
# Fa      38
# Gd      62
# Po       1
# TA    1237
# dtype: int64, 'BsmtExposure': BsmtExposure
# Av    213
# Gd    127
# Mn    111
# No    887
# dtype: int64, 'BsmtFinType1': BsmtFinType1
# ALQ    209
# BLQ    141
# GLQ    402
# LwQ     69
# Rec    125
# Unf    392
# dtype: int64, 'BsmtFinType2': BsmtFinType2
# ALQ      19
# BLQ      32
# GLQ      12
# LwQ      46
# Rec      53
# Unf    1176
# dtype: int64, 'Heating': Heating
# GasA    1318
# GasW      16
# Grav       3
# OthW       1
# dtype: int64, 'HeatingQC': HeatingQC
# Ex    704
# Fa     36
# Gd    217
# Po      1
# TA    380
# dtype: int64, 'CentralAir': CentralAir
# N      61
# Y    1277
# dtype: int64, 'Electrical': Electrical
# FuseA      76
# FuseF      17
# FuseP       2
# Mix         1
# SBrkr    1242
# dtype: int64, 'KitchenQual': KitchenQual
# Ex     97
# Fa     23
# Gd    568
# TA    650
# dtype: int64, 'Functional': Functional
# Maj1      10
# Maj2       4
# Min1      28
# Min2      30
# Mod       11
# Sev        1
# Typ     1254
# dtype: int64, 'GarageType': GarageType
# 2Types       6
# Attchd     852
# Basment     19
# BuiltIn     85
# CarPort      7
# Detchd     369
# dtype: int64, 'GarageFinish': GarageFinish
# Fin    345
# RFn    413
# Unf    580
# dtype: int64, 'GarageQual': GarageQual
# Ex       3
# Fa      48
# Gd      14
# Po       3
# TA    1270
# dtype: int64, 'GarageCond': GarageCond
# Ex       2
# Fa      33
# Gd       9
# Po       7
# TA    1287
# dtype: int64, 'PavedDrive': PavedDrive
# N      54
# P      27
# Y    1257
# dtype: int64, 'SaleType': SaleType
# COD        42
# CWD         4
# Con         2
# ConLD       6
# ConLI       4
# ConLw       4
# New       117
# Oth         1
# WD       1158
# dtype: int64, 'SaleCondition': SaleCondition
# Abnorml      86
# AdjLand       1
# Alloca        7
# Family       20
# Normal     1104
# Partial     120
# dtype: int64}

# %% [markdown]
# ###  Expected results:
#
# ```
# <class 'dict'>
# {'MSZoning': RL         1066
# RM          191
# FV           62
# RH           11
# C (all)       8
# Name: MSZoning, dtype: int64, 'Street': Pave    1333
# Grvl       5
# Name: Street, dtype: int64, 'LotShape': Reg    829
# IR1 459
# IR2     40
# IR3     10
# Name: LotShape, dtype: int64, 'LandContour': Lvl    1206
# BNK 52
# HLS      48
# Low      32
# Name: LandContour, dtype: int64, 'Utilities': AllPub    1337
# Nome avoid 1
# Name: Utilities, dtype: int64, 'LotConfig': Inside     957
# Corner     244
# CulDSac     90
# 43 difference
# Fr3 4
# Name: LotConfig, dtype: int64, 'LandSlope': Gtl    1265
# Mod      61
# Sev      12
# Name: LandSlope, dtype: int64, 'Neighborhood': NAmes      209
# Collgcr 146
# Oldtown 100
# Somerst     83
# Gilbert     77
# NridgHt     75
# The baby 73
# Edwards     70
# Sawyer      69
# SawyerW     53
# Crawfor     50
# Brxide 47
# Mitchel     42
# NoRidge     41
# Timber      37
# Idotrr 29
# ClearCr     26
# StoneBr     25
# Swisu 20
# Blmngtn     17
# Brdale 15
# MeadowV     12
# Veenker 11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64, 'Condition1': Norm      1162
# Feedr       63
# Artery      43
# RRAN 26
# Poson 19
# Rrae 10
# Put 8
# Rrn 5
# RRNe         2
# Name: Condition1, dtype: int64, 'Condition2': Norm      1324
# Feedr        5
# Artery       2
# Poson 2
# Rrn 2
# Put 1
# IRRAN 1
# Rrae 1
# Name: Condition2, dtype: int64, 'BldgType': 1Fam      1138
# Tunhse 112
# Tunhs 38
# Duplex      28
# 2fmCon      22
# Name: BldgType, dtype: int64, 'HouseStyle': 1Story    657
# 2Story    426
# 1.5pen 134
# SLvl       64
# SFOYER 30
# 1.5Unf     11
# 2.5Unf     10
# 2.5Fin 6
# Name: HouseStyle, dtype: int64, 'RoofStyle': Gable      1037
# Hip         272
# Flat         11
# Gambrel      10
# Mansard 6
# Shed          2
# Name: RoofStyle, dtype: int64, 'RoofMatl': CompShg    1314
# Tar & GRR9
# Wdshngl 6
# WdShake       5
# Roll          1
# Membrane 1
# ClyTile       1
# Metal         1
# Name: RoofMatl, dtype: int64, 'Exterior1st': VinylSd    486
# HdBoard    211
# MetalSd    201
# WD SDNG 183
# Plywood    100
# Cemntbd 52
# BrkFace     44
# Stucco 21
# WdShing     20
# AsbShng     15
# Stone        2
# Shimasta 1
# BrkComm      1
# CBlock       1
# Name: Exterior1st, dtype: int64, 'Exterior2nd': VinylSd    475
# MetalSd    197
# HdBoard    197
# WD SDNG 176
# Plywood    127
# CmentBd     51
# Wd Shng     32
# Stucco 23
# BrkFace     22
# AsbShng     16
# Shimastak 10
# Brk Cmn      6
# AsphShn      2
# Stone        2
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64, 'MasVnrType': None       763
# BrkFace    432
# Stone      128
# Brkcmn 15
# Name: MasVnrType, dtype: int64, 'ExterQual': TA    803
# Gd    477
# Ex     51
# Fa      7
# Name: ExterQual, dtype: int64, 'ExterCond': TA    1183
# Gd     137
# Fa      16
# Ex       2
# Name: ExterCond, dtype: int64, 'Foundation': PConc     620
# CBlock    580
# On the Brk 129
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64, 'BsmtQual': TA    594
# Gd    592
# Ex    120
# Fa     32
# Name: BsmtQual, dtype: int64, 'BsmtCond': TA    1237
# Gd      62
# Fa      38
# After 1
# Name: BsmtCond, dtype: int64, 'BsmtExposure': No    887
# Of 213
# Gd    127
# Mn    111
# Name: BsmtExposure, dtype: int64, 'BsmtFinType1': GLQ    402
# Unf    392
# Alq 209
# Fir 141
# Rec    125
# LWQ 69
# Name: BsmtFinType1, dtype: int64, 'BsmtFinType2': Unf    1176
# Rec      53
# Lwq 46
# Fir 32
# Alq 19
# GLQ      12
# Name: BsmtFinType2, dtype: int64, 'Heating': GasA    1318
# Neat 16
# Grav       3
# OTH 1
# Name: Heating, dtype: int64, 'HeatingQC': Ex    704
# By 380
# Gd    217
# Fa     36
# After 1
# Name: HeatingQC, dtype: int64, 'CentralAir': Y    1277
# N      61
# Name: CentralAir, dtype: int64, 'Electrical': SBrkr    1242
# FOUNA 76
# FuseF      17
# FuseP       2
# Mix         1
# Name: Electrical, dtype: int64, 'KitchenQual': TA    650
# Gd    568
# Ex     97
# Fa     23
# Name: KitchenQual, dtype: int64, 'Functional': Typ     1254
# With us 30
# Min1 28
# Mod       11
# Maj 1 10
# Maj2 4
# Sev        1
# Name: Functional, dtype: int64, 'GarageType': Attchd     852
# Dectering 369
# BuiltIn     85
# Basment     19
# CarPort      7
# 2Types       6
# Name: GarageType, dtype: int64, 'GarageFinish': Unf    580
# West Germany 413
# Fin    345
# Name: GarageFinish, dtype: int64, 'GarageQual': TA    1270
# Fa      48
# Gd      14
# After 3
# Ex       3
# Name: GarageQual, dtype: int64, 'GarageCond': TA    1287
# Fa      33
# Gd       9
# After 7
# Ex       2
# Name: GarageCond, dtype: int64, 'PavedDrive': Y    1257
# N      54
# P      27
# Name: PavedDrive, dtype: int64, 'SaleType': WD       1158
# New       117
# COD        42
# ConLD       6
# Conlw 4
# Congi 4
# CWD         4
# Con         2
# Oth         1
# Name: SaleType, dtype: int64, 'SaleCondition': Normal     1104
# Partial     120
# Abnorml      86
# Family       20
# Alloca 7
# Adjland 1
# Name: SaleCondition, dtype: int64}
# ```

# %% [markdown]
# ### Step 3
#
# You are given the ```dirty_str_house_prices.csv``` data. Your goal is to clean it using methods provided by ```pandas``` such as ```DataFrame.apply()```, ```DataFrame.str.lower()```, etc. Any non-alphanumeric characters can be considered noise.
#
# **Please be careful when exploring the data.**

# %%
#Начало вашего кода
dirty_data=pd.read_csv("dirty_str_house_prices.csv")
dirty_data.set_index("Id",inplace=True)
del dirty_data["Unnamed: 0"]
#Конец вашего кода
print(dirty_data)
# Out:
#      MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope  \
# Id
# 1         rl:   PAVE.     ;REg       \tlvl   AllPub.     InsidE:      gtl
# 2       ...RL   <PAVE    reg\t        Lvl;  AllPUb\t        FR2       Gtl<
# 3        ;Rl    Pave      ir1?        LVL!   Allpub!    ?inside     ...Gtl
# 4          rl   pave.     ;IR1        .Lvl  ;ALLPUB;     >Corner      ;GTL
# 5       .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub        ?fr2   .GTL...
# ...       ...     ...      ...         ...       ...         ...       ...
# 1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;
# 1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.
# 1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl
# 1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl
# 1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1        COLLGCR<      norm;      NORM.  ...     SBRKr         gd\t
# 2       veenker\t    ?FEedr.      ;norm  ...    \tSBRKR         ta?
# 3        ?COLLGCR      !Norm     .norm>  ...     sbrkr<         .Gd
# 4        .CRAWFOR       NORm      NORM:  ...    \tSbrkr         Gd<
# 5       ?NoRIdge>   ...NORM<      Norm;  ...    \tSbrkr         GD;
# ...           ...        ...        ...  ...        ...         ...
# 1456   \tGilbert:      Norm?       NORM  ...     >sbrkr         .ta
# 1457    ...NWAMEs    NORM...     \tnorm  ...      SBRKR         TA!
# 1458    >CRAWfoR<       Norm    Norm...  ...     Sbrkr;         !Gd
# 1459        names       norm    \tnorm.  ...   \tFUseA:         Gd!
# 1460    \tEdwards    !NORM\t      norm?  ...    ;SBRKR?        ;ta:
#
#      Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1           TYP    AttChd<         .RFn       TA\t      \tTA<         y?
# 2          ;TYP    Attchd>        RFn\t       \tTa      >TA\t        ;Y!
# 3        TyP...    Attchd;         ;RFN    \tTA...        TA           Y
# 4          !TYP  DETCHD...         UNF?      \tTa;        ;Ta         .Y
# 5         <Typ>   Attchd\t        !rfn>       TA\t         Ta       \tY>
# ...         ...        ...          ...        ...        ...        ...
# 1456       !TYP    ;Attchd         :RFn        TA<        :Ta         Y;
# 1457      MIn1?    ATTCHD<         :unf       >Ta>        ?TA       >Y\t
# 1458       :TyP    AttChD<         ?Rfn        >TA       :TA:         .Y
# 1459        TYP    attchd.          Unf       :Ta;       \tTA       ...Y
# 1460       typ:    .ATTCHD          FIn       >ta?      \tta<      >y...
#
#      SaleType SaleCondition
# Id
# 1         wd      \tNormal?
# 2         Wd        Normal.
# 3         WD;        NORMAL
# 4         wd.     ABNORML\t
# 5        ?WD!       NoRmAl>
# ...       ...           ...
# 1456      Wd?     normal...
# 1457      Wd;     \tNormal;
# 1458     >wd!      :NORMAL;
# 1459     <WD!       :normal
# 1460      Wd;       ;NORMAL
#
# [1338 rows x 38 columns]

# %% [markdown]
# ###  Expected results:
#
# ```
# MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope  \
# Id
# 1         rl:   PAVE.     ;REg       \tlvl   AllPub.     InsidE:      gtl
# 2       ...RL   <PAVE    reg\t        Lvl;  AllPUb\t        FR2       Gtl<
# 3        ;Rl    Pave      ir1?        LVL!   Allpub!    ?inside     ...Gtl
# 4          rl   pave.     ;IR1        .Lvl  ;ALLPUB;     >Corner      ;GTL
# 5       .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub        ?fr2   .GTL...
# ...       ...     ...      ...         ...       ...         ...       ...
# 1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;
# 1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.
# 1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl
# 1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl
# 1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...
#
# Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1        COLLGCR<      norm;      NORM.  ...     SBRKr         gd\t
# 2 Veenker \ T? Feedr.      ; norm ... \ tsbrk to?
# 3        ?COLLGCR      !Norm     .norm>  ...     sbrkr<         .Gd
# 4        .CRAWFOR       NORm      NORM:  ...    \tSbrkr         Gd<
# 5       ?NoRIdge>   ...NORM<      Norm;  ...    \tSbrkr         GD;
# ...           ...        ...        ...  ...        ...         ...
# 1456 \ Tgilbert: Norm?       NORM ...> SBRKR .TA
# 1457 ... NWAMES NORM ... \ TNORM ... SBRKR TA!
# 1458    >CRAWfoR<       Norm    Norm...  ...     Sbrkr;         !Gd
# 1459        names       norm    \tnorm.  ...   \tFUseA:         Gd!
# 1460    \tEdwards    !NORM\t      norm?  ...    ;SBRKR?        ;ta:
#
# Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1 TYP attent, \ttTA)
# 2 ;TYP Attchdd> RF\t >TE >TAt ;
# 3 typs ... Event;         ; Rfn \ tta ... Ta y
# 4 !TY DETCHD… UNF?      \tLate        ; Yes
# <Typ\t\t <Typd\t <Typd\t There is a glory
# ...         ...        ...          ...        ...        ...        ...
# 1456 !TY PRAIT< :RFs HATil.
# 1457 MI1?    ATTCHD< :unf ?TA>
# 1458 :TyP.Rfn >Rfn >TA: .Ye
# 1459 TYP TYP.          Unf :Yes;       \tTA ...These
# 1460 typ: .ATTCHD FIn > is?      \tta< >...
#
# Saletype salecondition
# Id
# 1         wd      \tNormal?
# 2         Wd        Normal.
# 3         WD;        NORMAL
# 4         wd.     ABNORML\t
# 5        ?WD!       NoRmAl>
# ...       ...           ...
# 1456      Wd?     normal...
# 1457      Wd;     \tNormal;
# 1458     >wd!      :NORMAL;
# 1459     <WD!       :normal
# 1460      Wd;       ;NORMAL
#
# [1338 rows x 38 columns]
# ```

# %%
dirty_data
# Out:
#      MSZoning  Street LotShape LandContour Utilities   LotConfig LandSlope  \
# Id
# 1         rl:   PAVE.     ;REg       \tlvl   AllPub.     InsidE:      gtl
# 2       ...RL   <PAVE    reg\t        Lvl;  AllPUb\t        FR2       Gtl<
# 3        ;Rl    Pave      ir1?        LVL!   Allpub!    ?inside     ...Gtl
# 4          rl   pave.     ;IR1        .Lvl  ;ALLPUB;     >Corner      ;GTL
# 5       .rl\t  PaVE\t   Ir1...        Lvl<   !Allpub        ?fr2   .GTL...
# ...       ...     ...      ...         ...       ...         ...       ...
# 1456      ?rl   PAVE>   ...Reg       >LVL<  Allpub\t  ...INSIDe:      GTL;
# 1457      Rl<   <PAVE      REG      ...lvl   Allpub:     .INsIDE      Gtl.
# 1458      ?RL   Pave!   ...Reg        >LVL   AlLPUb.     !InSiDE      >GTl
# 1459     RL\t   PAvE<     reg;      ?lvl\t   .AlLPUb     Inside:      :Gtl
# 1460     .rl!  <Pave:     Reg;     ...LVL?  .AlLPUb      INsIDe.    gtl...
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1        COLLGCR<      norm;      NORM.  ...     SBRKr         gd\t
# 2       veenker\t    ?FEedr.      ;norm  ...    \tSBRKR         ta?
# 3        ?COLLGCR      !Norm     .norm>  ...     sbrkr<         .Gd
# 4        .CRAWFOR       NORm      NORM:  ...    \tSbrkr         Gd<
# 5       ?NoRIdge>   ...NORM<      Norm;  ...    \tSbrkr         GD;
# ...           ...        ...        ...  ...        ...         ...
# 1456   \tGilbert:      Norm?       NORM  ...     >sbrkr         .ta
# 1457    ...NWAMEs    NORM...     \tnorm  ...      SBRKR         TA!
# 1458    >CRAWfoR<       Norm    Norm...  ...     Sbrkr;         !Gd
# 1459        names       norm    \tnorm.  ...   \tFUseA:         Gd!
# 1460    \tEdwards    !NORM\t      norm?  ...    ;SBRKR?        ;ta:
#
#      Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1           TYP    AttChd<         .RFn       TA\t      \tTA<         y?
# 2          ;TYP    Attchd>        RFn\t       \tTa      >TA\t        ;Y!
# 3        TyP...    Attchd;         ;RFN    \tTA...        TA           Y
# 4          !TYP  DETCHD...         UNF?      \tTa;        ;Ta         .Y
# 5         <Typ>   Attchd\t        !rfn>       TA\t         Ta       \tY>
# ...         ...        ...          ...        ...        ...        ...
# 1456       !TYP    ;Attchd         :RFn        TA<        :Ta         Y;
# 1457      MIn1?    ATTCHD<         :unf       >Ta>        ?TA       >Y\t
# 1458       :TyP    AttChD<         ?Rfn        >TA       :TA:         .Y
# 1459        TYP    attchd.          Unf       :Ta;       \tTA       ...Y
# 1460       typ:    .ATTCHD          FIn       >ta?      \tta<      >y...
#
#      SaleType SaleCondition
# Id
# 1         wd      \tNormal?
# 2         Wd        Normal.
# 3         WD;        NORMAL
# 4         wd.     ABNORML\t
# 5        ?WD!       NoRmAl>
# ...       ...           ...
# 1456      Wd?     normal...
# 1457      Wd;     \tNormal;
# 1458     >wd!      :NORMAL;
# 1459     <WD!       :normal
# 1460      Wd;       ;NORMAL
#
# [1338 rows x 38 columns]

# %%
pd_dirty_data=dirty_data.copy()

# %%
st1 = '..ST'
st2 = '.KZ'

# %%
def dirty_data(data):
    for column in data.columns:
        data[column] = data[column].str.replace(r'[^a-zA-Z0-9]', '', regex=True)
        data[column] = data[column].str.upper().str.strip()
    return data
    
pd_dirty_data=dirty_data(pd_dirty_data)

print(pd_dirty_data.head())
pd_dirty_data
# Out:
#    MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 2        RL   PAVE      REG         LVL    ALLPUB       FR2       GTL
# 3        RL   PAVE      IR1         LVL    ALLPUB    INSIDE       GTL
# 4        RL   PAVE      IR1         LVL    ALLPUB    CORNER       GTL
# 5        RL   PAVE      IR1         LVL    ALLPUB       FR2       GTL
#
#    Neighborhood Condition1 Condition2  ... Electrical KitchenQual Functional  \
# Id                                     ...
# 1       COLLGCR       NORM       NORM  ...      SBRKR          GD        TYP
# 2       VEENKER      FEEDR       NORM  ...      SBRKR          TA        TYP
# 3       COLLGCR       NORM       NORM  ...      SBRKR          GD        TYP
# 4       CRAWFOR       NORM       NORM  ...      SBRKR          GD        TYP
# 5       NORIDGE       NORM       NORM  ...      SBRKR          GD        TYP
#
#    GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# Id
# 1      ATTCHD          RFN         TA         TA          Y       WD
# 2      ATTCHD          RFN         TA         TA          Y       WD
# 3      ATTCHD          RFN         TA         TA          Y       WD
# 4      DETCHD          UNF         TA         TA          Y       WD
# 5      ATTCHD          RFN         TA         TA          Y       WD
#
#    SaleCondition
# Id
# 1         NORMAL
# 2         NORMAL
# 3         NORMAL
# 4        ABNORML
# 5         NORMAL
#
# [5 rows x 38 columns]
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 2          RL   PAVE      REG         LVL    ALLPUB       FR2       GTL
# 3          RL   PAVE      IR1         LVL    ALLPUB    INSIDE       GTL
# 4          RL   PAVE      IR1         LVL    ALLPUB    CORNER       GTL
# 5          RL   PAVE      IR1         LVL    ALLPUB       FR2       GTL
# ...       ...    ...      ...         ...       ...       ...       ...
# 1456       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1457       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1458       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1459       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1460       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 2         VEENKER      FEEDR       NORM  ...      SBRKR          TA
# 3         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 4         CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 5         NORIDGE       NORM       NORM  ...      SBRKR          GD
# ...           ...        ...        ...  ...        ...         ...
# 1456      GILBERT       NORM       NORM  ...      SBRKR          TA
# 1457       NWAMES       NORM       NORM  ...      SBRKR          TA
# 1458      CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 1459        NAMES       NORM       NORM  ...      FUSEA          GD
# 1460      EDWARDS       NORM       NORM  ...      SBRKR          TA
#
#      Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1           TYP     ATTCHD          RFN         TA         TA          Y
# 2           TYP     ATTCHD          RFN         TA         TA          Y
# 3           TYP     ATTCHD          RFN         TA         TA          Y
# 4           TYP     DETCHD          UNF         TA         TA          Y
# 5           TYP     ATTCHD          RFN         TA         TA          Y
# ...         ...        ...          ...        ...        ...        ...
# 1456        TYP     ATTCHD          RFN         TA         TA          Y
# 1457       MIN1     ATTCHD          UNF         TA         TA          Y
# 1458        TYP     ATTCHD          RFN         TA         TA          Y
# 1459        TYP     ATTCHD          UNF         TA         TA          Y
# 1460        TYP     ATTCHD          FIN         TA         TA          Y
#
#      SaleType SaleCondition
# Id
# 1          WD        NORMAL
# 2          WD        NORMAL
# 3          WD        NORMAL
# 4          WD       ABNORML
# 5          WD        NORMAL
# ...       ...           ...
# 1456       WD        NORMAL
# 1457       WD        NORMAL
# 1458       WD        NORMAL
# 1459       WD        NORMAL
# 1460       WD        NORMAL
#
# [1338 rows x 38 columns]

# %% [markdown]
# ### Expected results:
#
# ```
# MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 2          RL   PAVE      REG         LVL    ALLPUB       FR2       GTL
# 3          RL   PAVE      IR1         LVL    ALLPUB    INSIDE       GTL
# 4          RL   PAVE      IR1         LVL    ALLPUB    CORNER       GTL
# 5          RL   PAVE      IR1         LVL    ALLPUB       FR2       GTL
# ...       ...    ...      ...         ...       ...       ...       ...
# 1456       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1457       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1458       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1459       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
# 1460       RL   PAVE      REG         LVL    ALLPUB    INSIDE       GTL
#
# Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# Id                                       ...
# 1         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 2 Veenker Feed Spring ... Sbrk TA
# 3         COLLGCR       NORM       NORM  ...      SBRKR          GD
# 4         CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 5         NORIDGE       NORM       NORM  ...      SBRKR          GD
# ...           ...        ...        ...  ...        ...         ...
# 1456      GILBERT       NORM       NORM  ...      SBRKR          TA
# 1457 NWAMES NORM NORM ... SBRKR TA
# 1458      CRAWFOR       NORM       NORM  ...      SBRKR          GD
# 1459        NAMES       NORM       NORM  ...      FUSEA          GD
# 1460 Edwards Norm Norm ... Patience Ta
#
# Functional GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# Id
# 1 TYP ATCHD ATCHD ATCHD AND
# 2 ATTCHD RFN ATCHD ATCHD AND
# 3 TYP ATCHD ATCHD ATCHD AND
# 4 TYP DETCHD UNF THE ONF THE
# 5 TYP ATCHD ATCHD ATCHD AND
# ...         ...        ...          ...        ...        ...        ...
# 1456 TYP ATCHD RFN ATCHD AT
# 1457 min1 Attchd UNF TA Y Y
# 1458 TYP ATCHD RFN ATCHD AT
# 1459 TYP ATCHD ATCHD THE AND
# 1460 TYP ATCHD FING THE
#
# Saletype salecondition
# Id
# 1          WD        NORMAL
# 2          WD        NORMAL
# 3          WD        NORMAL
# 4          WD       ABNORML
# 5          WD        NORMAL
# ...       ...           ...
# 1456       WD        NORMAL
# 1457       WD        NORMAL
# 1458       WD        NORMAL
# 1459       WD        NORMAL
# 1460       WD        NORMAL
#
# [1338 rows x 38 columns]
# ```

# %% [markdown]
# ### Step 4
#
# After cleaning ```pd_dirty_data```, compare it with ```pd_data```. Do we need to make some changes to ```pd_data``` or/and ```pd_dirty_data``` to make a fair comparison? Implement ```compare_dataframes(pd_data, pd_dirty_data)``` function that will compare input ```DataFrames```.

# %%
#Начало вашего кода
def compare_dataframes(pd_data, pd_dirty_data):
    pd_data_upper = pd_data.copy()
    pd_dirty_data = pd_dirty_data.copy()
    for column in pd_data_upper.columns:
        if pd_data_upper[column].dtype == 'object':
            pd_data_upper[column] = pd_data_upper[column].fillna('None')
            pd_data_upper[column] = pd_data_upper[column].str.strip().str.upper()
    results = {}
    for column in pd_data_upper.columns:
        matches = (pd_data_upper[column] == pd_dirty_data[column]).sum()
        total = len(pd_data_upper)
        results[column] = (matches / total) * 100
    
    return pd.Series(results, name='(%) same')
    return data_need
#Конец вашего кода
print(compare_dataframes(pd_data, pd_dirty_data))
# Out:
# MSZoning          99.402093
# Street           100.000000
# LotShape         100.000000
# LandContour      100.000000
# Utilities        100.000000
# LotConfig        100.000000
# LandSlope        100.000000
# Neighborhood     100.000000
# Condition1       100.000000
# Condition2       100.000000
# BldgType         100.000000
# HouseStyle        87.967115
# RoofStyle        100.000000
# RoofMatl          99.327354
# Exterior1st       86.322870
# Exterior2nd       84.005979
# MasVnrType       100.000000
# ExterQual        100.000000
# ExterCond        100.000000
# Foundation       100.000000
# BsmtQual         100.000000
# BsmtCond         100.000000
# BsmtExposure     100.000000
# BsmtFinType1     100.000000
# BsmtFinType2     100.000000
# Heating          100.000000
# HeatingQC        100.000000
# CentralAir       100.000000
# Electrical       100.000000
# KitchenQual      100.000000
# Functional       100.000000
# GarageType       100.000000
# GarageFinish     100.000000
# GarageQual       100.000000
# GarageCond       100.000000
# PavedDrive       100.000000
# SaleType         100.000000
# SaleCondition    100.000000
# Name: (%) same, dtype: float64

# %% [markdown]
# ### Expected results:
#
# ```
# (%) same
# Mszoning 100,000000
# Street         100.000000
# Lotshepage 100.000000
# LandContour    100.000000
# Utilities      100.000000
# LotConfig      100.000000
# LandSlope      100.000000
# Neighborhood   100.000000
# Condition1 100.000000
# Condition2     100.000000
# BldgType       100.000000
# HouseStyle      87.967115
# ROOF STYLE 100.000000
# RoofMatl       100.000000
# Exterior1st    100.000000
# Exterior2nd    100.000000
# MasVnrType     100.000000
# ExterQual      100.000000
# ExterCond      100.000000
# Foundation     100.000000
# BsmtQual       100.000000
# BsmtCond       100.000000
# BsmtExposure   100.000000
# BsmtFinType1   100.000000
# BsmtFinType2   100.000000
# Heating        100.000000
# HeatingQC      100.000000
# CentralAir     100.000000
# Electrical     100.000000
# KitchenQual    100.000000
# Functional     100.000000
# Garage type 100.000000
# GarageFinish   100.000000
# GarageQual     100.000000
# GarageCond     100.000000
# PavedDrive     100.000000
# SaleType       100.000000
# Salecondition 100.000000
# ```

# %% [markdown]
# # Good Job!
